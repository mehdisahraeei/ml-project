# %% [markdown]
# # intro Linear Regression

# %% [markdown]
# <h2 id="importing_libraries">Importing required libraries</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# for example: y =  4x  + 4

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 4*(x) + 4 #formula

y_noise = 4 * np.random.normal(size=x.size) #for normlizing points
ydata = y + y_noise

plt.plot(x, ydata,  'go')
plt.plot(x,y, 'r--') 

plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.show()
